# %% [markdown]
# <a href="https://colab.research.google.com/github/anuvrat-umich/siads_milestone1/blob/anuvrat/input_data_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Exploring inputs

# %% [markdown]
# #### Importing libraries

# %%
### Defining libraries
import pandas as pd

# %% [markdown]
# #### Importing datasets to be used

# %%
input_path="..\input"

# %%
#Census income levels
#Income in the Past 12 Months (in 2022 Inflation-Adjusted Dollars) : ACSST5Y2022.S1901
df_income_1902=pd.read_csv(input_path+"\ACSST5Y2022-S1901-Data.csv")
df_income_1902.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-5fa10a47648a> in <cell line: 3>()
#       1 #Census income levels
#       2 #Income in the Past 12 Months (in 2022 Inflation-Adjusted Dollars) : ACSST5Y2022.S1901
# ----> 3 df_income_1902=pd.read_csv(input_path+"\ACSST5Y2022-S1901-Data.csv")
#       4 df_income_1902.head(5)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
#Health Outcomes
df_health_outcomes=pd.read_csv(input_path+"\PLACES__Local_Data_for_Better_Health__ZCTA_Data_2023_release_20240127.csv")
df_health_outcomes.head(5)
# Out:
# C:\Users\Anuvrat\AppData\Local\Temp\ipykernel_23304\3245527026.py:2: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_health_outcomes=pd.read_csv("..\input\PLACES__Local_Data_for_Better_Health__ZCTA_Data_2023_release_20240127.csv")
#    Year  LocationName DataSource               Category  \
# 0  2021          1001      BRFSS             Prevention
# 1  2021          1001      BRFSS        Health Outcomes
# 2  2021          1001      BRFSS  Health Risk Behaviors
# 3  2021          1001      BRFSS        Health Outcomes
# 4  2021          1001      BRFSS             Prevention
#
#                                              Measure Data_Value_Unit  \
# 0  Current lack of health insurance among adults ...               %
# 1             Arthritis among adults aged >=18 years               %
# 2        Binge drinking among adults aged >=18 years               %
# ...

# %%
#Social Determinants of Health
df_sdoh=pd.read_csv(input_path+"\SDOH_Measures_for_ZCTA__ACS_2017-2021_20240121.csv")
df_sdoh.head(5)
# Out:
#         Year  LocationName  DataSource Category  \
# 0  2017-2021         93420  5-year ACS     SDOH
# 1  2017-2021          6120  5-year ACS     SDOH
# 2  2017-2021          1810  5-year ACS     SDOH
# 3  2017-2021          4259  5-year ACS     SDOH
# 4  2017-2021          1128  5-year ACS     SDOH
#
#                                              Measure Data_Value_Unit  \
# 0                       Crowding among housing units               %
# 1  No broadband internet subscription among house...               %
# 2               Housing cost burden among households               %
# 3               Housing cost burden among households               %
# 4        Persons of racial or ethnic minority status               %
#
#   Data_Value_Type  Data_Value   MOE  TotalPopulation  LocationID CategoryID  \
# 0      Percentage         2.3   1.2            31864       93420       SDOH
# 1      Percentage        29.3   7.1            13399        6120       SDOH
# ...

# %%
#Policital affiliation by state    ### You will need to install openpyxl for read_excel to work
df_state_politics=pd.read_excel(input_path+"\States Political Affiliations Jan-2024.xlsx", sheet_name="Data")
df_state_politics.head(5)
# Out:
#        STATE(TERRITORY) Abbreviation  \
# 0            California           CA
# 1              Colorado           CO
# 2           Connecticut           CT
# 3              Delaware           DE
# 4  District of Columbia           DC
#
#   Political Affiliation (2008-2020 presidential elections)
# 0                                          Deep Blue
# 1                                          Deep Blue
# 2                                          Deep Blue
# 3                                          Deep Blue
# 4                                          Deep Blue

# %%
#Public health spending by state
df_state_public_spend=pd.read_csv(input_path+"\Per person state public health funding.csv", skiprows=6, dtype={'Fips': 'string'})
df_state_public_spend.head(5)
# Out:
#   Fips Location  TimeFrame Data Type      Data  MOE
# 0   01  Alabama       2017   Dollars  56.43214  NaN
# 1   01  Alabama       2018   Dollars  57.23000  NaN
# 2   01  Alabama       2019   Dollars  54.25000  NaN
# 3   01  Alabama       2020   Dollars  46.81000  NaN
# 4   01  Alabama       2021   Dollars  52.35000  NaN

# %%
#American Community Survey : ACSDP5Y2020.DP05
df_acs=pd.read_csv(input_path+"\ACSDP5Y2020.DP05-Data.csv", skiprows=1)
df_acs.head(5)
# Out:
# C:\Users\Anuvrat\AppData\Local\Temp\ipykernel_23304\4140081384.py:2: DtypeWarning: Columns (3,5,7,11,17,19,21,23,25,31,39,43,49,51,53,55,59,61,63,67,127,141,143,153) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_acs=pd.read_csv("..\input\ACSDP5Y2020.DP05-Data.csv", skiprows=1)
#         Geography Geographic Area Name  \
# 0  8600000US00601          ZCTA5 00601
# 1  8600000US00602          ZCTA5 00602
# 2  8600000US00603          ZCTA5 00603
# 3  8600000US00606          ZCTA5 00606
# 4  8600000US00610          ZCTA5 00610
#
#    Estimate!!SEX AND AGE!!Total population  \
# 0                                    16773
# 1                                    37083
# 2                                    45652
# 3                                     6231
# 4                                    26502
#
#   Margin of Error!!SEX AND AGE!!Total population  \
# 0                                            259
# 1                                            149
# ...

# %% [markdown]
# #### Keeping only selected fields and renaming them

# %%
df_income_1902
